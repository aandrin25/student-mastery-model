# %% [markdown]
# <a href="https://colab.research.google.com/github/aandrin25/student-mastery-model/blob/main/StudentMasteryModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
